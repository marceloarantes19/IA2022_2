# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X, y = datasets.load_diabetes(return_X_y=True)

# %%
X = X[:, np.newaxis, 2]

# %%
plt.scatter(X, y)

# %%
XTreino, XTeste, yTreino, yTeste = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
regr = LinearRegression()
regr.fit(XTreino, yTreino)
pred = regr.predict(XTeste)

# %%
XTeste[[0]]
# Out:
# array([[-0.00620595]])

# %%
pred[0]
# Out:
# 144.9079395729052

# %%
yTeste[0]
# Out:
# 219.0

# %%
plt.scatter(XTeste, yTeste, color="black")
plt.plot(XTeste, pred, color="blue", linewidth=3)
plt.show()
